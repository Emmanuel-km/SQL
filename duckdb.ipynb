# %% [markdown]
# The first step in every logical code is to import necessary libraries and accesories for the code to function

# %%
#imports

import pandas as pd
import numpy as np
import duckdb 

#checking imports
print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
print("DuckDB version:", duckdb.__version__)
# Out:
# Pandas version: 2.2.3
# NumPy version: 2.2.1
# DuckDB version: 1.4.1

# %% [markdown]
# Creating or checking the existing database file

# %%
conn = duckdb.connect('my_database')

# %% [markdown]
# ## WORKING WITH TABLES

# %% [markdown]
# ##### CREATING A TABLE

# %%
conn.execute('''CREATE TABLE mydeliverables (
    id DATE PRIMARY KEY,
    commit VARCHAR(100),
    description TEXT,
    status VARCHAR(50)
)''')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 conn.execute('''CREATE TABLE mydeliverables (
#       2     id DATE PRIMARY KEY,
#       3     commit VARCHAR(100),
#       4     description TEXT,
#       5     status VARCHAR(50)
#       6 )''')
#
# NameError: name 'conn' is not defined

# %% [markdown]
# checked
