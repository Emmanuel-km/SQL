# %%
import pandas as pd
import numpy as np
import duckdb

# %%
conn = duckdb.connect('customers.db')

# %%
conn.execute("""
    CREATE TABLE employees (
        id INTEGER,
        name VARCHAR,
        department VARCHAR,
        salary INTEGER,
        hire_date DATE
    )
""")
